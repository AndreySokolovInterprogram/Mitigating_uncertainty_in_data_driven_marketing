# %% [markdown]
# # Get VK groups

# %%
import requests
import time
import pandas as pd
import random
from google.colab import userdata

def search_vk_groups(access_token, keywords, total_count=5000):
    """
    Searches for VK groups by given keywords, extracts detailed information,
    and returns a list of dictionaries, including the number of subscribers.
    """
    found_groups = {}  # Dictionary to store unique groups (ID -> data)
    requests_count = 0

    for query in keywords:
        offset = 0
        while len(found_groups) < total_count:
            if requests_count >= 3:
                print("3 requests have been made, pausing for 1 second...")
                time.sleep(1)
                requests_count = 0

            print(f"Searching for '{query}' with an offset of {offset}. Found groups: {len(found_groups)}")

            api_url = "https://api.vk.com/method/groups.search"
            params = {
                'q': query,
                'type': 'group',
                'count': 1000,
                'offset': offset,
                'access_token': access_token,
                'v': '5.131',
                'fields': 'city,description,members_count'  # members_count added
            }

            try:
                response = requests.get(api_url, params=params)
                response.raise_for_status()
                data = response.json()

                if 'error' in data:
                    print(f"API error: {data['error']['error_msg']}")
                    break

                groups = data['response']['items']
                if not groups:
                    break

                for group in groups:
                    if group['id'] not in found_groups:
                        group_data = {
                            'group_id': group.get('id'),
                            'name': group.get('name', ''),
                            'city_id': group.get('city', {}).get('id', ''),
                            'city_name': group.get('city', {}).get('title', ''),
                            'description': group.get('description', ''),
                            'members_count': group.get('members_count', 0)  # Get the number of subscribers
                        }
                        found_groups[group['id']] = group_data

                offset += 1000
                requests_count += 1

                if len(groups) < 1000:
                    print(f"Found fewer than 1000 groups for the query '{query}', moving to the next one.")
                    break

            except requests.exceptions.RequestException as e:
                print(f"Request error: {e}")
                break

            if len(found_groups) >= total_count:
                print(f"The target number of groups ({total_count}) has been reached.")
                break

    return list(found_groups.values())

# --- Main script execution ---

MY_ACCESS_TOKEN = userdata.get('access_token')

if MY_ACCESS_TOKEN == "YOUR_ACCESS_TOKEN":
    print("Error: please replace 'YOUR_ACCESS_TOKEN' with your real access token.")
else:
    # Keywords for food delivery groups
    food_keywords = [
        'доставка еды', 'пицца', 'суши', 'бургеры', 'роллы',
        'еда на дом', 'доставка обедов', 'доставка шашлыка',
        'доставка пирогов', 'кулинария', 'catering'
    ]

    # Keywords for non-food delivery groups
    non_food_keywords = [
        'новости', 'юмор', 'мемы', 'фотография', 'спорт',
        'книги', 'фильмы', 'музыка', 'путешествия', 'искусство'
    ]
    # Get 5000 food delivery groups
    print("--- Parsing food delivery groups ---")
    food_delivery_groups = search_vk_groups(MY_ACCESS_TOKEN, food_keywords, total_count=5000)
    for group in food_delivery_groups:
        group['label'] = 1  # Label "food delivery"

    # Get 5000 non-food delivery groups
    print("\n--- Parsing non-food delivery groups ---")
    non_food_groups = search_vk_groups(MY_ACCESS_TOKEN, non_food_keywords, total_count=5000)
    for group in non_food_groups:
        group['label'] = 0 # Label "non-food delivery"

    # Combine both lists and shuffle
    all_groups = food_delivery_groups + non_food_groups
    random.shuffle(all_groups)

    print(f"\nCombined {len(all_groups)} groups. Saving to Excel...")

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(all_groups)

    # Save to Excel
    df.to_excel('vk_groups_dataset.xlsx', index=False)
    print("Data successfully saved to 'vk_groups_dataset.xlsx'.")
# Out:
# --- Parsing food delivery groups ---
# Searching for 'доставка еды' with an offset of 0. Found groups: 0
# Found fewer than 1000 groups for the query 'доставка еды', moving to the next one.
# Searching for 'пицца' with an offset of 0. Found groups: 997
# Searching for 'пицца' with an offset of 1000. Found groups: 1982
# Searching for 'суши' with an offset of 0. Found groups: 1982
# Found fewer than 1000 groups for the query 'суши', moving to the next one.
# 3 requests have been made, pausing for 1 second...
# Searching for 'бургеры' with an offset of 0. Found groups: 2868
# Found fewer than 1000 groups for the query 'бургеры', moving to the next one.
# Searching for 'роллы' with an offset of 0. Found groups: 3320
# Found fewer than 1000 groups for the query 'роллы', moving to the next one.
# Searching for 'еда на дом' with an offset of 0. Found groups: 3831
# Found fewer than 1000 groups for the query 'еда на дом', moving to the next one.
# 3 requests have been made, pausing for 1 second...
# Searching for 'доставка обедов' with an offset of 0. Found groups: 4810
# Found fewer than 1000 groups for the query 'доставка обедов', moving to the next one.
#
# --- Parsing non-food delivery groups ---
# Searching for 'новости' with an offset of 0. Found groups: 0
# Found fewer than 1000 groups for the query 'новости', moving to the next one.
# Searching for 'юмор' with an offset of 0. Found groups: 998
# Found fewer than 1000 groups for the query 'юмор', moving to the next one.
# Searching for 'мемы' with an offset of 0. Found groups: 1990
# Found fewer than 1000 groups for the query 'мемы', moving to the next one.
# 3 requests have been made, pausing for 1 second...
# Searching for 'фотография' with an offset of 0. Found groups: 2976
# Found fewer than 1000 groups for the query 'фотография', moving to the next one.
# Searching for 'спорт' with an offset of 0. Found groups: 3971
# Found fewer than 1000 groups for the query 'спорт', moving to the next one.
# Searching for 'книги' with an offset of 0. Found groups: 4967
# Found fewer than 1000 groups for the query 'книги', moving to the next one.
#
# Combined 11617 groups. Saving to Excel...
# Data successfully saved to 'vk_groups_dataset.xlsx'.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11617 entries, 0 to 11616
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   group_id       11617 non-null  int64
#  1   name           11617 non-null  object
#  2   city_id        11617 non-null  object
#  3   city_name      11617 non-null  object
#  4   description    11617 non-null  object
#  5   members_count  11617 non-null  int64
#  6   label          11617 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 635.4+ KB

# %%
df = df[df['description'].str.strip() != '']
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10646 entries, 0 to 11616
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   group_id       10646 non-null  int64
#  1   name           10646 non-null  object
#  2   city_id        10646 non-null  object
#  3   city_name      10646 non-null  object
#  4   description    10646 non-null  object
#  5   members_count  10646 non-null  int64
#  6   label          10646 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 665.4+ KB
# None

# %%
df['label'].value_counts()
# Out:
# label
# 1    5407
# 0    5239
# Name: count, dtype: int64

# %% [markdown]
# # Get VK posts

# %%
import requests
import pandas as pd
import time
import os

# Replace with your actual token
MY_ACCESS_TOKEN = userdata.get('access_token')

def get_posts_and_filter(access_token, group_id, total_count=300):
    """
    Downloads posts (up to the last 300) and removes posts with low activity.
    """
    api_url = "https://api.vk.com/method/wall.get"
    all_posts = []
    offset = 0
    remaining_posts = total_count

    # Calculate the number of requests, each for 100 posts
    num_requests = (total_count + 99) // 100

    print(f"Attempting to get {total_count} posts, which will require {num_requests} request(s).")

    for i in range(num_requests):
        params = {
            'owner_id': -group_id,
            'count': min(100, remaining_posts),
            'offset': offset,
            'access_token': access_token,
            'v': '5.131'
        }

        try:
            response = requests.get(api_url, params=params)
            response.raise_for_status()
            data = response.json()

            if 'error' in data:
                print(f"API error when getting posts: {data['error']['error_msg']}")
                return [], None

            posts = data['response']['items']
            all_posts.extend(posts)

            # If fewer posts were received than requested, it's the end.
            if len(posts) < 100:
                print(f"Received fewer than 100 posts, finishing. Total: {len(all_posts)}")
                break

            # Increase the offset for the next request
            offset += 100
            remaining_posts -= 100

        except requests.exceptions.RequestException as e:
            print(f"Request error when getting posts: {e}")
            return [], None


    # Filter posts from the last year
    current_timestamp = int(time.time())
    one_year_ago = current_timestamp - 31536000  # 365 * 24 * 60 * 60

    relevant_posts = [post for post in all_posts if post['date'] >= one_year_ago]

    if not relevant_posts:
        print(f"No posts found for the last year for group {group_id}")
        return [], None

    # Calculate average activity
    total_activity = sum(p.get('likes', {}).get('count', 0) +
                         p.get('comments', {}).get('count', 0) +
                         p.get('reposts', {}).get('count', 0) for p in relevant_posts)

    if len(relevant_posts) > 0:
        avg_activity = total_activity / len(relevant_posts)
    else:
        avg_activity = 0

    print(f"Average activity in group {group_id}: {avg_activity:.2f}")

    # Filter posts with activity above average
    filtered_posts = [
        p for p in relevant_posts
        if (p.get('likes', {}).get('count', 0) +
            p.get('comments', {}).get('count', 0) +
            p.get('reposts', {}).get('count', 0)) > avg_activity
    ]

    return filtered_posts, data['response']['count']


def main():
    try:
        # For security, use environment variables if you are working with sensitive data
        # MY_ACCESS_TOKEN = os.environ.get("VK_API_TOKEN", "YOUR_ACCESS_TOKEN")
        df = pd.read_excel('vk_groups_dataset.xlsx')
    except FileNotFoundError:
        print("Error: 'vk_groups_dataset.xlsx' file not found. Please make sure it exists.")
        return

    print("Searching for the 100 most popular groups...")

    # 0. Keep only food delivery groups
    food_groups = df[df['label'] == 1]
    food_groups.reset_index(drop=True, inplace=True)

    # 1. Top 100 most popular groups.
    top_100_groups = food_groups.sort_values(by='members_count', ascending=False).head(100)
    print("Top 100 groups:")
    print(top_100_groups[['name', 'members_count']].to_string())

    # 2. Downloading and processing posts
    all_posts_data = []

    for _, row in top_100_groups.iterrows():
        group_id = row['group_id']
        group_name = row['name']
        print(f"\nProcessing group '{group_name}' (ID: {group_id})...")

        time.sleep(1)

        # Call the modified function, which now downloads 300 posts
        filtered_posts, total_posts_count = get_posts_and_filter(MY_ACCESS_TOKEN, group_id, total_count=300)

        if total_posts_count is not None:
            print(f"Total posts found: {total_posts_count}, after filtering: {len(filtered_posts)}")

        for post in filtered_posts:
            post_data = {
                'project': group_name,
                'account': group_id,
                'date': pd.to_datetime(post.get('date'), unit='s'),
                'type': 'post',
                'link': f"https://vk.com/wall{-group_id}_{post.get('id')}",
                'text': post.get('text', ''),
                'likes': post.get('likes', {}).get('count', 0),
                'comments': post.get('comments', {}).get('count', 0),
                'reposts': post.get('reposts', {}).get('count', 0),
                'views': post.get('views', {}).get('count', 0)
            }
            all_posts_data.append(post_data)

    if not all_posts_data:
        print("\nNo suitable posts found. The table will not be created.")
        return

    # 3. Saving to Excel
    final_df = pd.DataFrame(all_posts_data)

    # Clean and order columns
    final_df = final_df[[
        'project', 'account', 'date', 'type', 'link',
        'text', 'likes', 'comments', 'reposts', 'views'
    ]]

    print(f"\nTotal of {len(final_df)} posts found and processed.")
    final_df.to_excel('vk_posts_data.xlsx', index=False)
    print("Data successfully saved to 'vk_posts_data.xlsx'.")

if __name__ == "__main__":
    if MY_ACCESS_TOKEN == "YOUR_ACCESS_TOKEN":
        print("Please replace 'YOUR_ACCESS_TOKEN' with your real access token.")
    else:
        main()
# Out:
# Searching for the 100 most popular groups...
# Top 100 groups:
#                                                   name  members_count
# 3649              Закрутки на зиму и заготовки на зиму         762724
# 3284  Про100 еда | Рецепты  | Салаты | Выпечка | Торты         627984
# 3699                                          Суши Wok         452234
# 1330                             Чиббис - доставка еды         437902
# 2975       Правильное питание. Здоровая еда. Julromanj         294419
# 5015                                       Суши Мастер         256100
# 5535                              Группа PIZZA (Пицца)         251941
# 5598                        Додо Пицца Санкт-Петербург         207773
# 119                        ЗОЖ ПП ЕДА и легкие рецепты         177507
# 612                Оригами - доставка суши, Красноярск         126407
# 1723                 YO!FISH | суши, роллы, пицца, вок         114552
# 1491                              Додо Пицца Краснодар         114149
# 2605           Вкусная еда - кулинарные рецепты с фото         112872
# 3117                                          Суши Бай         109803
# 3653                              Суши SELL Красноярск         107139
# 3856                                  🧄Еда на изнанку🧆         102545
# 5272                           Додо Пицца Екатеринбург         100606
# 2731                              Додо Пицца Челябинск         100321
# 1557                                      Планета Суши          92359
# 2425                 Додо Пицца Тюмень. Доставка пиццы          91183
# 1052                                   Додо Пицца Омск          91040
# 656                   Фуджи | Еда, друзья, впечатления          88481
# 285                СУШИ 74 | Челябинск | доставка суши          88002
# 1389                                       Суши-Маркет          87218
# 3078                            ВКУСНЫЕ СУШИ!Доставка!          85965
# 1195                               Додо Пицца Тольятти          81607
# 5008                 ЦУНАМИ - Доставка суши Красноярск          79487
# 2012                                       Пицца Мафия          78360
# 3633        СушиПицца74 суши и пицца Челябинск Копейск          73109
# 5237                      Сушиопт! Доставка суши! Уфа!          72775
# 2335                                  Додо Пицца Пермь          71882
# 3711            Жако роллы и пицца Тольятти | Доставка          69306
# 396                        Fidele Доставка любимой еды          66706
# 3137    Ёбидоёби — доставка суши и роллов | Красноярск          64765
# 5640  Стерео суши | Доставка суши, роллов | Красноярск          63986
# 4482                                  Додо Пицца Киров          60880
# 3831                              Додо Пицца Сыктывкар          60223
# 2525             Миори Акции Оренбург | Роллы | Пицца|          60084
# 4779                       Додо Пицца Саратов, Энгельс          59435
# 3575      Европа Пицца Киров • Доставка роллов и пиццы          59297
# 2810     Суши Тайм - роллы и пицца | Доставка Белгород          59081
# 3518           Кафе ЭДО | Доставка.Суши.Пицца.Тольятти          58544
# 2554                            Додо Пицца Новосибирск          58413
# 4225  Доставка роллов, суши и пиццы на дом - Суши Good          58017
# 1658               ПантаО • Суши - Роллы Доставка  ДНР          57559
# 122                                       Ниндзя Пицца          57289
# 380                                Додо Пицца Беларусь          57267
# 1248              Самара | Доставка роллы, суши, пицца          56320
# 139           доставка Black Roll's | суши роллы пицца          52810
# 1032   Мистер Ролл доставка суши,Биг роллы,WOK Саранск          52425
# 5409                        Пицца Роллы | Куба | Курск          52093
# 96         Суши Фуд | Доставка еды: суши, роллы, пицца          50602
# 2415       Доставка пирогов | Обедов | Санкт-Петербург          50471
# 828          Sushi-Bro | Суши • Роллы • Пицца | Ижевск          50439
# 4007                                    Сушкоф и пицца          50111
# 5647  Суши в дом Воронеж. Доставка суши, роллов, пиццы          49596
# 743                      BIG FISH  | Суши Петрозаводск          48319
# 3252                                  Додо Пицца Пенза          47998
# 720       Камикадзе - суши, пицца | Доставка Челябинск          47241
# 1237        NinjaFood | Курск | Доставка пицца и роллы          46996
# 3408          Додо Пицца Курган | Доставка пиццы  24/7          46937
# 4864                              Пицца Куба | Воронеж          46591
# 4525    Каратэ Суши - кафе с доставкой Нижний Новгород          46499
# 1361                                      Галерея Суши          45700
# 4243     Севастополь "ЯМАТО" Доставка суши роллы пиццы          44348
# 1605                         Еда на любой вкус рецепты          43986
# 3428            Суши Рыба | Доставка Красноярск Ачинск          43609
# 4267          Суши Гурмэ| Доставка Роллов, Пиццы и WOK          43070
# 1129       Миори | Оренбург: Суши Роллы Пицца Доставка          42548
# 3703              Жако роллы и пицца Самара | Доставка          42144
# 1541                                Додо Пицца Вологда          41802
# 4172                                       Хигаси суши          41660
# 126           Суши Тайм Самара • Доставка роллов, суши          40632
# 3202                Домашняя еда и фермерские продукты          40515
# 125       Папа Джонс Новосибирск | Пицца «Papa John's»          40443
# 2367               Суши Жемчужина Красноярск 214-30-20          40413
# 1510  Суши Маркет|суши пицца доставка Великий Новгород          40201
# 1087                     LA PIZZA | Воронеж | ЛА ПИЦЦА          39522
# 2847    Тренировки питание похудение набор Sport i Eda          39520
# 2720                             Суши Бар НАМИ | Пермь          39208
# 2671                                   Додо Пицца Чита          38793
# 1100                  Свой дом,  свой сад, своя земля.          38264
# 1595                       BigRolls | Роллы Суши Киров          38219
# 257          Пицца Синица | Доставка пиццы Новосибирск          38117
# 2785                                    Додо Пицца Уфа          37884
# 5292                             Додо Пицца Красноярск          37647
# 2388                  Суши Хаус Луганск | Доставка еды          37280
# 5440         Ёбидоёби — доставка суши и роллов | Питер          37223
# 5327                  РОЛЛЫ ПАЛЫ | Курск доставка суши          36785
# 22                    Buffet СУШИ & ПИЦЦА | Красноярск          36018
# 2753                                  УХ ТЫ СУШИ! Ухта          35828
# 2095                   Додо Пицца Комсомольск-на-Амуре          35686
# 3670      Ёбидоёби — доставка суши и роллов |  Иркутск          35380
# 4400                       Ольга Эрбис. Еда без границ          35063
# 5476           Доставка суши и роллы «ТОКИО» г. Ижевск          34837
# 4834            Гризли роллы и суши | Доставка Луганск          34391
# 4900              Додо Пицца Смоленск | Доставка пиццы          34193
# 3780         Кушай Суши и Пиццу | Роллы | Магнитогорск          34137
# 3143                               Курск | Люблю Пицца          34091
# 826      KING SIZE ROLL — суши, роллы, wok | Челябинск          34047
#
# Processing group 'Закрутки на зиму и заготовки на зиму' (ID: 99822529)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 99822529: 659.39
# Total posts found: 66702, after filtering: 76
#
# Processing group 'Про100 еда | Рецепты  | Салаты | Выпечка | Торты' (ID: 87276395)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 87276395: 40.94
# Total posts found: 59469, after filtering: 38
#
# Processing group 'Суши Wok' (ID: 34273828)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 34273828: 26.70
# Total posts found: 19381, after filtering: 98
#
# Processing group 'Чиббис - доставка еды' (ID: 89373035)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 89373035: 791.98
# Total posts found: 2812, after filtering: 32
#
# Processing group 'Правильное питание. Здоровая еда. Julromanj' (ID: 154236304)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 154236304: 452.56
# Total posts found: 2178, after filtering: 96
#
# Processing group 'Суши Мастер' (ID: 68535127)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 68535127: 3272.84
# Total posts found: 8709, after filtering: 167
#
# Processing group 'Группа PIZZA (Пицца)' (ID: 12080041)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 12080041: 538.97
# Total posts found: 5340, after filtering: 38
#
# Processing group 'Додо Пицца Санкт-Петербург' (ID: 113851128)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 113851128: 548.90
# Total posts found: 11318, after filtering: 16
#
# Processing group 'ЗОЖ ПП ЕДА и легкие рецепты' (ID: 225287452)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 225287452: 642.40
# Total posts found: 2382, after filtering: 75
#
# Processing group 'Оригами - доставка суши, Красноярск' (ID: 13448690)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 13448690: 75.89
# Total posts found: 52411, after filtering: 25
#
# Processing group 'YO!FISH | суши, роллы, пицца, вок' (ID: 57439266)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 57439266: 120.95
# Total posts found: 8272, after filtering: 48
#
# Processing group 'Додо Пицца Краснодар' (ID: 83706700)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 83706700: 39.75
# Total posts found: 11173, after filtering: 82
#
# Processing group 'Вкусная еда - кулинарные рецепты с фото' (ID: 29096194)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 29096194: 20.58
# Total posts found: 46210, after filtering: 50
#
# Processing group 'Суши Бай' (ID: 77550696)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 77550696: 63.00
# Total posts found: 1528, after filtering: 41
#
# Processing group 'Суши SELL Красноярск' (ID: 58013513)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 58013513: 43.84
# Total posts found: 48445, after filtering: 67
#
# Processing group '🧄Еда на изнанку🧆' (ID: 217576460)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 217576460: 219.69
# Total posts found: 10134, after filtering: 60
#
# Processing group 'Додо Пицца Екатеринбург' (ID: 83709377)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 83709377: 250.08
# Total posts found: 7896, after filtering: 58
#
# Processing group 'Додо Пицца Челябинск' (ID: 43621561)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 43621561: 100.74
# Total posts found: 12759, after filtering: 54
#
# Processing group 'Планета Суши' (ID: 35929257)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 35929257: 2.64
# Total posts found: 5173, after filtering: 57
#
# Processing group 'Додо Пицца Тюмень. Доставка пиццы' (ID: 65396740)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 65396740: 65.79
# Total posts found: 18096, after filtering: 106
#
# Processing group 'Додо Пицца Омск' (ID: 129222099)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 129222099: 115.58
# Total posts found: 7724, after filtering: 42
#
# Processing group 'Фуджи | Еда, друзья, впечатления' (ID: 34607671)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 34607671: 64.12
# Total posts found: 22799, after filtering: 7
#
# Processing group 'СУШИ 74 | Челябинск | доставка суши' (ID: 78057583)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 78057583: 91.50
# Total posts found: 5959, after filtering: 75
#
# Processing group 'Суши-Маркет' (ID: 47323487)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 47323487: 186.96
# Total posts found: 12980, after filtering: 5
#
# Processing group 'ВКУСНЫЕ СУШИ!Доставка!' (ID: 54288406)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 54288406: 28.48
# Total posts found: 5223, after filtering: 22
#
# Processing group 'Додо Пицца Тольятти' (ID: 103887121)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 103887121: 16.75
# Total posts found: 19262, after filtering: 59
#
# Processing group 'ЦУНАМИ - Доставка суши Красноярск' (ID: 19196078)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 19196078: 178.51
# Total posts found: 34054, after filtering: 7
#
# Processing group 'Пицца Мафия' (ID: 39720099)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 39720099: 17.30
# Total posts found: 9389, after filtering: 19
#
# Processing group 'СушиПицца74 суши и пицца Челябинск Копейск' (ID: 61333822)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 61333822: 241.73
# Total posts found: 6568, after filtering: 29
#
# Processing group 'Сушиопт! Доставка суши! Уфа!' (ID: 46701897)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 46701897: 2.45
# Total posts found: 14266, after filtering: 51
#
# Processing group 'Додо Пицца Пермь' (ID: 137903427)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 137903427: 201.46
# Total posts found: 6370, after filtering: 54
#
# Processing group 'Жако роллы и пицца Тольятти | Доставка' (ID: 62653794)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 62653794: 111.11
# Total posts found: 37343, after filtering: 11
#
# Processing group 'Fidele Доставка любимой еды' (ID: 57476778)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 57476778: 111.48
# Total posts found: 15141, after filtering: 11
#
# Processing group 'Ёбидоёби — доставка суши и роллов | Красноярск' (ID: 106401916)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 106401916: 56.46
# Total posts found: 10566, after filtering: 20
#
# Processing group 'Стерео суши | Доставка суши, роллов | Красноярск' (ID: 34535599)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 34535599: 58.50
# Total posts found: 24311, after filtering: 4
#
# Processing group 'Додо Пицца Киров' (ID: 113851758)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 113851758: 51.14
# Total posts found: 14821, after filtering: 51
#
# Processing group 'Додо Пицца Сыктывкар' (ID: 29220398)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 29220398: 21.09
# Total posts found: 35474, after filtering: 56
#
# Processing group 'Миори Акции Оренбург | Роллы | Пицца|' (ID: 110950309)...
# Attempting to get 300 posts, which will require 3 request(s).
# Received fewer than 100 posts, finishing. Total: 284
# Average activity in group 110950309: 5.37
# Total posts found: 283, after filtering: 106
#
# Processing group 'Додо Пицца Саратов, Энгельс' (ID: 53420634)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 53420634: 30.54
# Total posts found: 13886, after filtering: 40
#
# Processing group 'Европа Пицца Киров • Доставка роллов и пиццы' (ID: 94419056)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 94419056: 237.66
# Total posts found: 20252, after filtering: 39
#
# Processing group 'Суши Тайм - роллы и пицца | Доставка Белгород' (ID: 87074888)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 87074888: 74.46
# Total posts found: 26407, after filtering: 56
#
# Processing group 'Кафе ЭДО | Доставка.Суши.Пицца.Тольятти' (ID: 58950790)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 58950790: 89.36
# Total posts found: 22172, after filtering: 56
#
# Processing group 'Додо Пицца Новосибирск' (ID: 83706647)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 83706647: 301.96
# Total posts found: 12995, after filtering: 52
#
# Processing group 'Доставка роллов, суши и пиццы на дом - Суши Good' (ID: 105630095)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 105630095: 31.64
# Total posts found: 14373, after filtering: 46
#
# Processing group 'ПантаО • Суши - Роллы Доставка  ДНР' (ID: 48609084)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 48609084: 37.13
# Total posts found: 7338, after filtering: 59
#
# Processing group 'Ниндзя Пицца' (ID: 25939403)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 25939403: 86.13
# Total posts found: 9336, after filtering: 59
#
# Processing group 'Додо Пицца Беларусь' (ID: 121500185)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 121500185: 61.58
# Total posts found: 4486, after filtering: 19
#
# Processing group 'Самара | Доставка роллы, суши, пицца' (ID: 118810417)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 118810417: 34.20
# Total posts found: 8364, after filtering: 37
#
# Processing group 'доставка Black Roll's | суши роллы пицца' (ID: 129290687)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 129290687: 13.47
# Total posts found: 6056, after filtering: 109
#
# Processing group 'Мистер Ролл доставка суши,Биг роллы,WOK Саранск' (ID: 72831992)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 72831992: 95.20
# Total posts found: 12417, after filtering: 55
#
# Processing group 'Пицца Роллы | Куба | Курск' (ID: 125309896)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 125309896: 186.52
# Total posts found: 1948, after filtering: 48
#
# Processing group 'Суши Фуд | Доставка еды: суши, роллы, пицца' (ID: 60410126)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 60410126: 41.24
# Total posts found: 8404, after filtering: 57
#
# Processing group 'Доставка пирогов | Обедов | Санкт-Петербург' (ID: 24891491)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 24891491: 152.74
# Total posts found: 10257, after filtering: 79
#
# Processing group 'Sushi-Bro | Суши • Роллы • Пицца | Ижевск' (ID: 120669112)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 120669112: 41.95
# Total posts found: 17916, after filtering: 16
#
# Processing group 'Сушкоф и пицца' (ID: 11567735)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 11567735: 82.49
# Total posts found: 12596, after filtering: 34
#
# Processing group 'Суши в дом Воронеж. Доставка суши, роллов, пиццы' (ID: 76645233)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 76645233: 4.99
# Total posts found: 6585, after filtering: 64
#
# Processing group 'BIG FISH  | Суши Петрозаводск' (ID: 117862376)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 117862376: 298.24
# Total posts found: 4494, after filtering: 27
#
# Processing group 'Додо Пицца Пенза' (ID: 138891246)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 138891246: 12.83
# Total posts found: 11090, after filtering: 67
#
# Processing group 'Камикадзе - суши, пицца | Доставка Челябинск' (ID: 32640929)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 32640929: 143.47
# Total posts found: 7914, after filtering: 123
#
# Processing group 'NinjaFood | Курск | Доставка пицца и роллы' (ID: 83610102)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 83610102: 178.44
# Total posts found: 9119, after filtering: 24
#
# Processing group 'Додо Пицца Курган | Доставка пиццы  24/7' (ID: 141708756)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 141708756: 53.55
# Total posts found: 6446, after filtering: 65
#
# Processing group 'Пицца Куба | Воронеж' (ID: 164538912)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 164538912: 108.56
# Total posts found: 5036, after filtering: 21
#
# Processing group 'Каратэ Суши - кафе с доставкой Нижний Новгород' (ID: 38596207)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 38596207: 91.27
# Total posts found: 6907, after filtering: 66
#
# Processing group 'Галерея Суши' (ID: 42831299)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 42831299: 123.94
# Total posts found: 6612, after filtering: 16
#
# Processing group 'Севастополь "ЯМАТО" Доставка суши роллы пиццы' (ID: 158505934)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 158505934: 237.01
# Total posts found: 30014, after filtering: 81
#
# Processing group 'Еда на любой вкус рецепты' (ID: 117850415)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 117850415: 659.22
# Total posts found: 1555, after filtering: 89
#
# Processing group 'Суши Рыба | Доставка Красноярск Ачинск' (ID: 33184696)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 33184696: 42.95
# Total posts found: 15557, after filtering: 10
#
# Processing group 'Суши Гурмэ| Доставка Роллов, Пиццы и WOK' (ID: 43973528)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 43973528: 9.73
# Total posts found: 9346, after filtering: 85
#
# Processing group 'Миори | Оренбург: Суши Роллы Пицца Доставка' (ID: 225914784)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 225914784: 35.77
# Total posts found: 437, after filtering: 44
#
# Processing group 'Жако роллы и пицца Самара | Доставка' (ID: 146011630)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 146011630: 94.44
# Total posts found: 17665, after filtering: 11
#
# Processing group 'Додо Пицца Вологда' (ID: 94821909)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 94821909: 64.70
# Total posts found: 17787, after filtering: 62
#
# Processing group 'Хигаси суши' (ID: 48827718)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 48827718: 114.93
# Total posts found: 24504, after filtering: 22
#
# Processing group 'Суши Тайм Самара • Доставка роллов, суши' (ID: 1384328)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 1384328: 49.19
# Total posts found: 26793, after filtering: 38
#
# Processing group 'Домашняя еда и фермерские продукты' (ID: 143104947)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 143104947: 18.67
# Total posts found: 21340, after filtering: 135
#
# Processing group 'Папа Джонс Новосибирск | Пицца «Papa John's»' (ID: 54498174)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 54498174: 71.63
# Total posts found: 7106, after filtering: 72
#
# Processing group 'Суши Жемчужина Красноярск 214-30-20' (ID: 49782045)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 49782045: 34.90
# Total posts found: 10374, after filtering: 25
#
# Processing group 'Суши Маркет|суши пицца доставка Великий Новгород' (ID: 44197168)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 44197168: 96.12
# Total posts found: 8138, after filtering: 24
#
# Processing group 'LA PIZZA | Воронеж | ЛА ПИЦЦА' (ID: 164356518)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 164356518: 42.34
# Total posts found: 699, after filtering: 35
#
# Processing group 'Тренировки питание похудение набор Sport i Eda' (ID: 55173011)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 55173011: 36.13
# Total posts found: 52658, after filtering: 44
#
# Processing group 'Суши Бар НАМИ | Пермь' (ID: 24757650)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 24757650: 14.52
# Total posts found: 1759, after filtering: 26
#
# Processing group 'Додо Пицца Чита' (ID: 148699456)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 148699456: 25.85
# Total posts found: 4686, after filtering: 26
#
# Processing group 'Свой дом,  свой сад, своя земля.' (ID: 88938708)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 88938708: 98.43
# Total posts found: 5583, after filtering: 82
#
# Processing group 'BigRolls | Роллы Суши Киров' (ID: 40325071)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 40325071: 23.61
# Total posts found: 7252, after filtering: 20
#
# Processing group 'Пицца Синица | Доставка пиццы Новосибирск' (ID: 51945689)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 51945689: 18.75
# Total posts found: 10193, after filtering: 22
#
# Processing group 'Додо Пицца Уфа' (ID: 118780998)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 118780998: 16.18
# Total posts found: 9929, after filtering: 49
#
# Processing group 'Додо Пицца Красноярск' (ID: 165998812)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 165998812: 16.03
# Total posts found: 9055, after filtering: 61
#
# Processing group 'Суши Хаус Луганск | Доставка еды' (ID: 142568208)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 142568208: 11.31
# Total posts found: 6417, after filtering: 19
#
# Processing group 'Ёбидоёби — доставка суши и роллов | Питер' (ID: 166594281)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 166594281: 26.05
# Total posts found: 4466, after filtering: 22
#
# Processing group 'РОЛЛЫ ПАЛЫ | Курск доставка суши' (ID: 14819519)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 14819519: 31.91
# Total posts found: 4431, after filtering: 40
#
# Processing group 'Buffet СУШИ & ПИЦЦА | Красноярск' (ID: 50487252)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 50487252: 59.83
# Total posts found: 13571, after filtering: 35
#
# Processing group 'УХ ТЫ СУШИ! Ухта' (ID: 61532563)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 61532563: 1995.10
# Total posts found: 448, after filtering: 5
#
# Processing group 'Додо Пицца Комсомольск-на-Амуре' (ID: 92987072)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 92987072: 103.21
# Total posts found: 17788, after filtering: 7
#
# Processing group 'Ёбидоёби — доставка суши и роллов |  Иркутск' (ID: 168032376)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 168032376: 48.54
# Total posts found: 5450, after filtering: 57
#
# Processing group 'Ольга Эрбис. Еда без границ' (ID: 77812739)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 77812739: 584.34
# Total posts found: 1481, after filtering: 81
#
# Processing group 'Доставка суши и роллы «ТОКИО» г. Ижевск' (ID: 34297859)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 34297859: 9.78
# Total posts found: 10022, after filtering: 22
#
# Processing group 'Гризли роллы и суши | Доставка Луганск' (ID: 127352059)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 127352059: 32.61
# Total posts found: 830, after filtering: 12
#
# Processing group 'Додо Пицца Смоленск | Доставка пиццы' (ID: 32935323)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 32935323: 15.33
# Total posts found: 18317, after filtering: 30
#
# Processing group 'Кушай Суши и Пиццу | Роллы | Магнитогорск' (ID: 116069179)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 116069179: 91.88
# Total posts found: 15199, after filtering: 41
#
# Processing group 'Курск | Люблю Пицца' (ID: 32758521)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 32758521: 60.13
# Total posts found: 9857, after filtering: 18
#
# Processing group 'KING SIZE ROLL — суши, роллы, wok | Челябинск' (ID: 57913316)...
# Attempting to get 300 posts, which will require 3 request(s).
# Average activity in group 57913316: 75.68
# Total posts found: 1189, after filtering: 11
#
# Total of 4710 posts found and processed.
# Data successfully saved to 'vk_posts_data.xlsx'.

# %% [markdown]
# Simple markup

# %%
import pandas as pd
import re
import time

def classify_post_improved(text):
    """
    Improved function to classify post text into 5 categories using
    regular expressions and expanded dictionaries for increased accuracy.
    0 - non-committal
    1 - obligating to give a discount
    2 - obligating to give a gift
    3 - obligating to give cashback
    4 - obligating to deliver on time
    """
    if not isinstance(text, str) or not text.strip():
        return 0

    text_lower = text.lower()

    # --- EXPANDED DICTIONARIES WITH REGULAR EXPRESSIONS ---

    # Class 4: On-time delivery (the rarest, check first)
    delivery_keywords = [
        r'\bдостав\S+ за \d+\s*(минут|час|дня)', r'доставим (вовремя|в срок)',
        r'гарант\S+ доставк\S+', r'опозда\S+ —', r'если опоздаем',
        r'быстр\S+ доставк\S+', r'экспресс-доставк\S+',
        r'привезем к \d{2}:\d{2}', r'доставка точно ко времени'
    ]
    if any(re.search(pattern, text_lower) for pattern in delivery_keywords):
        return 4

    # Class 3: Cashback
    cashback_keywords = [
        r'к[еэ]шб[еэ]к\S*', r'cashback', r'возвращаем \d+%', r'верн[её]м \d+%',
        r'\bбалл\S+ за покупк\S+', r'программ\S+ лояльност\S+',
        r'копи\S+ балл\S+', r'начисли\S+ бонус\S+', r'бонус\S+ на сч[её]т'
    ]
    if any(re.search(pattern, text_lower) for pattern in cashback_keywords):
        return 3

    # --- Check for Gift and Discount ---
    # First, determine the presence of indicators, then decide which class to assign

    # Class 2: Gift
    gift_keywords = [
        r'подар\S+', r'розыгрыш\S*', r'конкурс\S*', r'\bприз\S*',
        r'\bбесплатн\S+', r'выиграй\S*', r'победител\S*', r'\bдарим\b',
        r'разыгрываем', r'1\s*\+\s*1', r'третий в подарок', r'второй бесплатно'
    ]

    # Class 1: Discount
    discount_keywords = [
        r'скидк\S*', r'промокод\S*', r'купон\S*', r'спец\S*предложен\S+',
        r'дисконт\S*', r'-\d+%', r'скидка \d+%', r'\bакци\S+',
        r'распродаж\S*', r'снижен\S+ цен\S*', r'выгод\S+'
    ]

    # Check the flags
    is_gift = any(re.search(pattern, text_lower) for pattern in gift_keywords)
    is_discount = any(re.search(pattern, text_lower) for pattern in discount_keywords)

    # Priority logic: Gift (Class 2) is more important than Discount (Class 1)
    if is_gift:
        # Even if there is a mention of a discount, a giveaway or a gift is a stronger obligation
        return 2

    if is_discount:
        # This block will only be triggered if no gift indicators were found
        return 1

    # Class 0: non-committal (default)
    return 0

# --- Main code block (remains unchanged) ---

# Load data
try:
    df = pd.read_excel('vk_posts_data.xlsx')
    print("File 'vk_posts_data.xlsx' successfully loaded.")
except FileNotFoundError:
    print("Error: File 'vk_posts_data.xlsx' not found.")
    exit()

# Check for 'text' column
if 'text' not in df.columns:
    print(f"Error: The file must have a 'text' column. Found columns: {df.columns.tolist()}")
    exit()

print("Starting post classification...")
start_time = time.time()

# Apply the improved classification function
df['class'] = df['text'].apply(classify_post_improved)

end_time = time.time()
print(f"Classification completed in {end_time - start_time:.2f} seconds.")

# View class distribution for analysis
print("\nPost distribution by class:")
print(df['class'].value_counts().sort_index())

# Create and save the final DataFrame
result_df = df[['text', 'class']]
output_filename = 'vk_posts_classified.xlsx'
result_df.to_excel(output_filename, index=False)

print(f"\nClassification completed. Results saved to file '{output_filename}'")
# Out:
# File 'vk_posts_data.xlsx' successfully loaded.
# Starting post classification...
# Classification completed in 0.46 seconds.
#
# Post distribution by class:
# class
# 0    2864
# 1     209
# 2    1616
# 3      10
# 4      11
# Name: count, dtype: int64
#
# Classification completed. Results saved to file 'vk_posts_classified.xlsx'

# %% [markdown]
# Balancing classes

# %%
import pandas as pd
from sklearn.utils import resample # Convenient library for these tasks

# --- SETTINGS ---
INPUT_FILE = 'vk_posts_classified.xlsx' # File with results from the previous step
OUTPUT_FILE = 'vk_posts_balanced.xlsx'  # Name of the file for the balanced dataset
SAMPLES_PER_CLASS = 500                 # Target number of examples for each class
RANDOM_STATE = 42                       # For reproducibility of results

# --- LOAD DATA ---
try:
    df = pd.read_excel(INPUT_FILE)
    print(f"File '{INPUT_FILE}' successfully loaded.")
    print("\nOriginal class distribution:")
    print(df['class'].value_counts().sort_index())
except FileNotFoundError:
    print(f"Error: File '{INPUT_FILE}' not found. Make sure it is in the same folder.")
    exit()

# --- BALANCING ---
print(f"\nStarting balancing. Goal: {SAMPLES_PER_CLASS} posts for each class...")

# Create an empty DataFrame for the balanced data
df_balanced = pd.DataFrame()

# Iterate through each unique class in the dataset
for post_class in df['class'].unique():
    df_class = df[df['class'] == post_class]

    # Apply Undersampling or Oversampling
    df_class_resampled = resample(
        df_class,
        replace=len(df_class) < SAMPLES_PER_CLASS, # replace=True for Oversampling (increase)
        n_samples=SAMPLES_PER_CLASS,
        random_state=RANDOM_STATE
    )

    # Add the processed class to the main DataFrame
    df_balanced = pd.concat([df_balanced, df_class_resampled])

print("\nBalancing complete!")

# --- RESULT ---
print("\nNew class distribution:")
print(df_balanced['class'].value_counts().sort_index())

# Shuffle the final dataset so that the classes are not in order
df_balanced = df_balanced.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)

# Save the balanced dataset to a new Excel file
df_balanced.to_excel(OUTPUT_FILE, index=False)

print(f"\nBalanced dataset saved to file '{OUTPUT_FILE}'.")
print(f"Final dataset size: {len(df_balanced)} rows.")
# Out:
# File 'vk_posts_classified.xlsx' successfully loaded.
#
# Original class distribution:
# class
# 0    2864
# 1     209
# 2    1616
# 3      10
# 4      11
# Name: count, dtype: int64
#
# Starting balancing. Goal: 500 posts for each class...
#
# Balancing complete!
#
# New class distribution:
# class
# 0    500
# 1    500
# 2    500
# 3    500
# 4    500
# Name: count, dtype: int64
#
# Balanced dataset saved to file 'vk_posts_balanced.xlsx'.
# Final dataset size: 2500 rows.
